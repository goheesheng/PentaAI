# %% [markdown]
# # Importing Libaries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.preprocessing .image import ImageDataGenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %% [markdown]
# # Image Data Agumentation

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# # Loading the data and performing data agumentation

# %%
x_train = train_datagen.flow_from_directory(r"Dataset\\dataset\\train",target_size = (64,64),batch_size = 32,class_mode = "categorical")
x_test = test_datagen.flow_from_directory(r"Dataset\\dataset\\test",target_size = (64,64),batch_size = 32,class_mode = "categorical")

train_generator = train_datagen.flow_from_directory(
    r"Dataset\\dataset\\train\\",
    target_size=(64, 64),
    batch_size=32,
    class_mode='sparse',
    color_mode='grayscale',
)

test_generator = test_datagen.flow_from_directory(
    r"Dataset\\dataset\\test\\",
    target_size=(64, 64),
    batch_size=32,
    class_mode='sparse',
    color_mode='grayscale',
 
)
# Out:
# Found 10496 images belonging to 7 classes.
# Found 3500 images belonging to 7 classes.
# Found 10496 images belonging to 7 classes.
# Found 3500 images belonging to 7 classes.

# %%
x_train.class_indices
# Out:
# {'circle': 0,
#  'parallelogram': 1,
#  'rectangle': 2,
#  'rhombus': 3,
#  'square': 4,
#  'trapezoid': 5,
#  'triangle': 6}

# %%
# get the mapping between class names and their indices
class_indices = train_generator.class_indices

# invert the mapping to get the class names from the indices
class_names = {v: k for k, v in class_indices.items()}

# get the next batch of images and labels from the train generator
x_batch, y_batch = next(train_generator)

# plot a few sample images
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(10, 5))
for i, ax in enumerate(axes.flat):
    ax.imshow(x_batch[i], cmap='gray')
    class_index = y_batch[i].argmax()  # get the index of the class with the highest probability
    class_name = class_names[class_index]  # get the class name from the index
    ax.set_title(f"Label: {class_name}")
    ax.axis('off')
    
plt.show()

# %% [markdown]
# # Building the Model

# %%
model = Sequential()
model.add(Convolution2D(32,(3,3),input_shape = (64,64,1)))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(units = 128, kernel_initializer= "random_uniform",activation = "relu"))
model.add(Dense(units = 7 , kernel_initializer= "random_uniform",activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  flatten (Flatten)           (None, 30752)             0
#
#  dense (Dense)               (None, 128)               3936384
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 3,937,607
# Trainable params: 3,937,607
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile and Fit the Model

# %% [markdown]
# ### Set CallBack
# The training loop will be checked at end of every epoch for whether the loss is no longer decreasing. Once it's found no longer decreasing, the training terminates. This prevents overfitting
#
# patience indicates the number of epochs with no improvement after which training will be stopped.
# monitor indicates the quantity to be monitored. In this case, it will be the loss

# %%
#set callback
callback = EarlyStopping(monitor='loss', patience=5)

# monitor: Quantity to be monitored.
# patience: Number of epochs with no improvement after which training will be stopped.

# %%
model.compile(optimizer= "adam",loss = "sparse_categorical_crossentropy" , metrics =["accuracy"])

# %%
model_history = model.fit(train_generator, epochs = 20 , validation_data = test_generator,validation_steps = 10,callbacks=[callback])
# Out:
# Epoch 1/20
# 328/328 [==============================] - 75s 215ms/step - loss: 1.6114 - accuracy: 0.3912 - val_loss: 1.0760 - val_accuracy: 0.6187
# Epoch 2/20
# 328/328 [==============================] - 17s 51ms/step - loss: 0.9310 - accuracy: 0.6861 - val_loss: 0.3715 - val_accuracy: 0.9062
# Epoch 3/20
# 328/328 [==============================] - 16s 49ms/step - loss: 0.4054 - accuracy: 0.8689 - val_loss: 0.2106 - val_accuracy: 0.9312
# Epoch 4/20
# 328/328 [==============================] - 16s 50ms/step - loss: 0.2533 - accuracy: 0.9161 - val_loss: 0.1360 - val_accuracy: 0.9500
# Epoch 5/20
# 328/328 [==============================] - 17s 51ms/step - loss: 0.2096 - accuracy: 0.9267 - val_loss: 0.1127 - val_accuracy: 0.9594
# Epoch 6/20
# 328/328 [==============================] - 15s 47ms/step - loss: 0.1812 - accuracy: 0.9322 - val_loss: 0.1508 - val_accuracy: 0.9500
# Epoch 7/20
# 328/328 [==============================] - 17s 51ms/step - loss: 0.1677 - accuracy: 0.9363 - val_loss: 0.0909 - val_accuracy: 0.9656
# Epoch 8/20
# 328/328 [==============================] - 15s 46ms/step - loss: 0.1675 - accuracy: 0.9371 - val_loss: 0.0639 - val_accuracy: 0.9844
# Epoch 9/20
# 328/328 [==============================] - 16s 49ms/step - loss: 0.1555 - accuracy: 0.9410 - val_loss: 0.1370 - val_accuracy: 0.9625
# Epoch 10/20
# 328/328 [==============================] - 17s 51ms/step - loss: 0.1613 - accuracy: 0.9378 - val_loss: 0.1061 - val_accuracy: 0.9656
# Epoch 11/20
# 328/328 [==============================] - 15s 46ms/step - loss: 0.1476 - accuracy: 0.9425 - val_loss: 0.0890 - val_accuracy: 0.9812
# Epoch 12/20
# 328/328 [==============================] - 15s 47ms/step - loss: 0.1495 - accuracy: 0.9412 - val_loss: 0.0706 - val_accuracy: 0.9719
# Epoch 13/20
# 328/328 [==============================] - 15s 46ms/step - loss: 0.1465 - accuracy: 0.9425 - val_loss: 0.0648 - val_accuracy: 0.9875
# Epoch 14/20
# 328/328 [==============================] - 15s 46ms/step - loss: 0.1421 - accuracy: 0.9443 - val_loss: 0.0842 - val_accuracy: 0.9781
# Epoch 15/20
# 328/328 [==============================] - 15s 47ms/step - loss: 0.1256 - accuracy: 0.9506 - val_loss: 0.0784 - val_accuracy: 0.9625
# Epoch 16/20
# 328/328 [==============================] - 15s 47ms/step - loss: 0.1403 - accuracy: 0.9441 - val_loss: 0.0857 - val_accuracy: 0.9594
# Epoch 17/20
# 328/328 [==============================] - 16s 48ms/step - loss: 0.1390 - accuracy: 0.9486 - val_loss: 0.1394 - val_accuracy: 0.9469
# Epoch 18/20
# 328/328 [==============================] - 15s 45ms/step - loss: 0.1350 - accuracy: 0.9454 - val_loss: 0.0839 - val_accuracy: 0.9719
# Epoch 19/20
# 328/328 [==============================] - 14s 42ms/step - loss: 0.1364 - accuracy: 0.9435 - val_loss: 0.1181 - val_accuracy: 0.9750
# Epoch 20/20
# 328/328 [==============================] - 15s 44ms/step - loss: 0.1304 - accuracy: 0.9466 - val_loss: 0.0479 - val_accuracy: 0.9812

# %% [markdown]
# 4.2 Evaluate Model Function
# #This function is used to evaluvate the models' performance on the training and testing dataset
# def eval_CNN_model(CNN_model,CNN_version):
#     _, CNN_train_acc = CNN_model.evaluate(x_train, y_train, verbose=0) #accuracy on training dataset
#     _, CNN_test_acc = CNN_model.evaluate(x_test, y_test, verbose=0) #accuracy on testing dataset
#     CNN_prediction=CNN_model.predict(x_test)
#     print('CNN {} Training Data Accuracy:'.format(CNN_version),round(CNN_train_acc*100,2),"%")
#     print('CNN {} Testing Data Accuracy:'.format(CNN_version),round(CNN_test_acc*100,2), '%')
#     print('CNN {} Testing Data F1-Score: {}'.format(CNN_version,round(f1_score(y_test, CNN_prediction.argmax(axis=1), average='macro'),3))) #f1-score on testing dataset
#     return CNN_prediction.argmax(axis=1)
# #This function is used to evaluvate the models' performance on the training and testing dataset
# def eval_CNN_model(CNN_model,CNN_version):
#     _, CNN_train_acc = CNN_model.evaluate(x_train, y_train, verbose=0) #accuracy on training dataset
#     _, CNN_test_acc = CNN_model.evaluate(x_test, y_test, verbose=0) #accuracy on testing dataset
#     CNN_prediction=CNN_model.predict(x_test)
#     print('CNN {} Training Data Accuracy:'.format(CNN_version),round(CNN_train_acc*100,2),"%")
#     print('CNN {} Testing Data Accuracy:'.format(CNN_version),round(CNN_test_acc*100,2), '%')
#     print('CNN {} Testing Data F1-Score: {}'.format(CNN_version,round(f1_score(y_test, CNN_prediction.argmax(axis=1), average='macro'),3))) #f1-score on testing dataset
#     return CNN_prediction.argmax(axis=1)
# 4.3 Plot Confusion Matrix Function & Print Classification Report

# %%
### Plot Accuracy & Loss Graph Function

# %%
#This function is used to plot the accuracy and loss graph from the history
def plot_loss_accuracy_graph(CNN_history, graph_title):
    plt.rc('font', size=10) #controls default text size
    plt.rc('axes', titlesize=10) #fontsize of the title
    plt.rc('axes', labelsize=10) #fontsize of the x and y labels
    plt.rc('xtick', labelsize=10) #fontsize of the x tick labels
    plt.rc('ytick', labelsize=10) #fontsize of the y tick labels
    plt.rc('legend', fontsize=10) #fontsize of the legend
    loss = CNN_history.history['loss'] #get loss
    val_loss = CNN_history.history['val_loss'] #get val loss
    acc = CNN_history.history['accuracy'] #get accuracy
    val_acc = CNN_history.history['val_accuracy'] #get val accuracy
    epoch = range(len(loss)) #number of epochs

    plt.figure(figsize=(20, 8)) #plot graph
    plt.suptitle(('{}'.format(graph_title)), fontsize=30)
    plt.subplot(1, 2, 1)
    plt.plot(epoch,loss,label='loss')
    plt.plot(epoch,val_loss,label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epoch,acc,label='acc')
    plt.plot(epoch,val_acc,label='val_acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

# %%
### Evaluate Model Function

# %%
### Plot Confusion Matrix Function & Print Classification Report

# %%
#This function is used to plot the confusion matrix and print the classification report
def confusion_matrix_classification_report(CNN_prediction,CNN_version):
    print(classification_report(y_test,CNN_prediction)) #print classification report
    print("---------------------------------------------------------------")
    CNN_confusion_matrix = confusion_matrix(y_test, CNN_prediction) #plot confusion matrix
    sns.set(font_scale=5)
    plt.figure(figsize=(100,50))
    sns.heatmap(CNN_confusion_matrix, annot=True,cmap="Blues")
    plt.title('CNN {} Confusion Matrix'.format(CNN_version),fontsize=100)
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()

# %%
plot_loss_accuracy_graph(model_history, "Base Model - Ee Sheng Model")

# %%
model_predictions=eval_CNN_model(model,"Ee Sheng Base Model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model_predictions=eval_CNN_model(model,"Ee Sheng Base Model")
#
# Cell In[14], line 3, in eval_CNN_model(CNN_model, CNN_version)
#       2 def eval_CNN_model(CNN_model,CNN_version):
# ----> 3     _, CNN_train_acc = CNN_model.evaluate(x_train, y_train, verbose=0) #accuracy on training dataset
#       4     _, CNN_test_acc = CNN_model.evaluate(x_test, y_test, verbose=0) #accuracy on testing dataset
#       5     CNN_prediction=CNN_model.predict(x_test)
#
# NameError: name 'y_train' is not defined

# %%
confusion_matrix_classification_report(model_predictions,"Ee Sheng - Base Model")

# %% [markdown]
# # Saving our model

# %%
model.save(r"C:\Users\gohee\Desktop\PentaAI\Flask\shapes.h5")

# %%
model = load_model(r"C:\Users\gohee\Desktop\PentaAI\Flask\shapes.h5")

# %% [markdown]
# # Predicting

# %%
img1 = image.load_img(r"C:\Users\gohee\Desktop\PentaAI\Dataset\dataset\train\circle\circle-2000.jpg", color_mode='grayscale',target_size = (64,64))
x = image.img_to_array(img1)
x = np.expand_dims(x, axis=0)  # Add an extra dimension to the input data

# %%
x.shape

# %%
prediction = model.predict(x)

# %%
predicted_class = np.argmax(prediction)

# %%
xpred

# %%
img2 = image.load_img(r"C:\Users\gohee\Desktop\PentaAI\Dataset\dataset\test\trapezoid\trapezoid-2000", color_mode='grayscale',target_size = (64,64))

# %%
y = image.img_to_array(img2)

# %%
y.shape

# %%
ypred = np.argmax(model.predict(y))

# %%
ypred

# %%
index = ['circle', 'parallelogram', 'rectangle','rhombus','square','trapezoid','triangle']

# %%
prediction = index[xpred]

# %%
prediction

# %%
prediction = index[ypred]

# %%
prediction
